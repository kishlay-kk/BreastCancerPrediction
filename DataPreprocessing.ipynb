# %%
# %matplotlib inline
import matplotlib.pyplot as plt

#Load libraries for data processing
import pandas as pd #data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np
from scipy.stats import norm

# visualization
import seaborn as sns 
plt.style.use('fivethirtyeight')
sns.set_style("white")


plt.rcParams['figure.figsize'] = (8,4) 
#plt.rcParams['axes.titlesize'] = 'large'

data = pd.read_csv('data/clean-data.csv', index_col=False)
data.drop('Unnamed: 0',axis=1, inplace=True)
#data.head()

# %%
#creating X and Y
array = data.values
X = array[:,1:31]
y = array[:,0]

# %%
#Label Encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.25, random_state=7)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((426, 30), (426,), (143, 30), (143,))

# %%
from sklearn.preprocessing import StandardScaler

# Normalization
scaler =StandardScaler()
Xs = scaler.fit_transform(X)
# Out:
# C:\Users\kishl\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\kishl\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
from sklearn.decomposition import PCA
# feature extraction
pca = PCA(n_components=10)
fit = pca.fit(Xs)

# summarize components
print(fit.components_)
# Out:
# [[ 2.18902444e-01  1.03724578e-01  2.27537293e-01  2.20994985e-01
#    1.42589694e-01  2.39285354e-01  2.58400481e-01  2.60853758e-01
#    1.38166959e-01  6.43633464e-02  2.05978776e-01  1.74280281e-02
#    2.11325916e-01  2.02869635e-01  1.45314521e-02  1.70393451e-01
#    1.53589790e-01  1.83417397e-01  4.24984216e-02  1.02568322e-01
#    2.27996634e-01  1.04469325e-01  2.36639681e-01  2.24870533e-01
#    1.27952561e-01  2.10095880e-01  2.28767533e-01  2.50885971e-01
#    1.22904556e-01  1.31783943e-01]
#  [-2.33857132e-01 -5.97060883e-02 -2.15181361e-01 -2.31076711e-01
#    1.86113023e-01  1.51891610e-01  6.01653628e-02 -3.47675005e-02
#    1.90348770e-01  3.66575471e-01 -1.05552152e-01  8.99796818e-02
#   -8.94572342e-02 -1.52292628e-01  2.04430453e-01  2.32715896e-01
#    1.97207283e-01  1.30321560e-01  1.83848000e-01  2.80092027e-01
#   -2.19866379e-01 -4.54672983e-02 -1.99878428e-01 -2.19351858e-01
#    1.72304352e-01  1.43593173e-01  9.79641143e-02 -8.25723507e-03
#    1.41883349e-01  2.75339469e-01]
#  [-8.53124282e-03  6.45499033e-02 -9.31421970e-03  2.86995259e-02
#   -1.04291904e-01 -7.40915709e-02  2.73383797e-03 -2.55635406e-02
#   -4.02399363e-02 -2.25740897e-02  2.68481387e-01  3.74633665e-01
#    2.66645367e-01  2.16006528e-01  3.08838979e-01  1.54779718e-01
#    1.76463743e-01  2.24657567e-01  2.88584292e-01  2.11503764e-01
#   -4.75069900e-02 -4.22978227e-02 -4.85465083e-02 -1.19023182e-02
#    4.26194128e-02  3.62512832e-02  3.05585049e-02  7.93942263e-02
#    2.05852303e-01  8.40196179e-02  7.24679669e-02 -3.61707220e-02
#    2.28225156e-01  4.83605709e-02]
#  [-2.23109907e-01  1.12698979e-01 -2.23739303e-01 -1.95586208e-01
#    6.42472034e-03 -1.67840508e-01  4.05911040e-02 -1.11971364e-01
#    2.56040091e-01 -1.23741218e-01  2.49984938e-01 -2.46645509e-01
#    2.27153477e-01  2.29160587e-01 -1.41924772e-01 -1.45323557e-01
#    3.58107175e-01  2.72520154e-01 -3.04077022e-01 -2.13722448e-01
#   -1.12141428e-01  1.03341704e-01 -1.09614419e-01 -8.07322276e-02
#    1.12315708e-01 -1.00677465e-01  1.61908402e-01  6.04882478e-02
#    6.46376505e-02 -1.34174160e-01]
#  [ 9.54861448e-02  2.40934177e-01  8.63854109e-02  7.49563274e-02
#   -6.92928405e-02  1.29371478e-02 -1.35601834e-01  8.05425428e-03
#    5.72069347e-01  8.11027440e-02 -4.95477668e-02 -2.89142623e-01
#   -1.14509004e-01 -9.19271047e-02  1.60884546e-01  4.35041464e-02
#   -1.41276621e-01  8.62415416e-02 -3.16529818e-01  3.67542316e-01
#    7.73616374e-02  2.95507472e-02  5.05082201e-02  6.99217453e-02
#   -1.28304531e-01 -1.72133287e-01 -3.11638422e-01 -7.66491459e-02
#   -2.95629185e-02  1.26094272e-02]]

# %%
X_pca = pca.transform(Xs)

PCA_df = pd.DataFrame()

PCA_df['PCA_1'] = X_pca[:,0]
PCA_df['PCA_2'] = X_pca[:,1]

plt.plot(PCA_df['PCA_1'][data.diagnosis == 'M'],PCA_df['PCA_2'][data.diagnosis == 'M'],'o', alpha = 0.7, color = 'r')
plt.plot(PCA_df['PCA_1'][data.diagnosis == 'B'],PCA_df['PCA_2'][data.diagnosis == 'B'],'o', alpha = 0.7, color = 'b')

plt.xlabel('PCA_1')
plt.ylabel('PCA_2')
plt.legend(['Malignant','Benign'])
plt.show()

# %%
#The amount of variance that each PC explains
var= pca.explained_variance_ratio_

# %%
var= pca.explained_variance_ratio_
#Cumulative Variance explains
var1=np.cumsum(np.round(pca.explained_variance_ratio_, decimals=4)*100)
print(var1)

plt.plot(var)
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Eigenvalue')

leg = plt.legend(['Eigenvalues from PCA'], loc='best', borderpad=0.3,shadow=False,markerscale=0.4)
leg.get_frame().set_alpha(0.4)
leg.draggable(state=True)
plt.show()
# Out:
# [44.27 63.24 72.63 79.23 84.73 88.75 91.   92.59 93.98 95.15]
# C:\Users\kishl\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:1196: MatplotlibDeprecationWarning:
# Legend.draggable() is drepecated in favor of Legend.set_draggable(). Legend.draggable may be reintroduced as a property in future releases.
#   message="Legend.draggable() is drepecated in "
